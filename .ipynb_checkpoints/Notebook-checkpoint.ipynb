# %%
import pandas as pd

curr_df = pd.read_json('data/deviation.json')

# %%
curr_df
# Out:
#                   name  gt_corners  rb_corners       mean        max  \
# 0         Schlafzimmer           4           4   3.956313   8.562939
# 1                Küche           4           4  23.019122  52.605437
# 2             Bathroom           4           4   1.013833   1.950322
# 3         Lounge/Diner           8           8   3.832620  18.236935
# 4           Essbereich           4           4   8.017758  15.642853
# ...                ...         ...         ...        ...        ...
# 1342    Master Bedroom           4           4   1.739907   4.703960
# 1343  Master Bedroom 2           4           4   0.530908   0.786997
# 1344          Zimmer I           4           4   0.880569   1.221873
# 1345  Hallway Bathroom           6           6  24.923452  64.266820
# 1346         Bedroom 4           4           4   0.387328   0.762659
#
#            min  floor_mean  floor_max  floor_min  ceiling_mean  ceiling_max  \
# ...

# %%
b = curr_df['gt_corners'] - curr_df['rb_corners']

# %%
for i in b:
    if i != 0:
        print(i)
#количество углов совпадает между ожидаемыми и полученными моделью

# %%
import matplotlib.pyplot as plt

# %%
for i in range(len(curr_df))

# %%
curr_df.index[0]
# Out:
# 0

# %%
plt.plot([1,4,38,13,23])

# %%
plt.plot(curr_df.index, curr_df['gt_corners'])

# %%
plt.plot(curr_df.index, curr_df['gt_corners']-curr_df['rb_corners'])

# %%
plt.title('Diffenrence in number of corners', fontsize=15)
plt.xlabel('Diffence', fontsize=12, color='black')
plt.ylabel('Number of rooms', fontsize=12, color='black')
plt.legend()
plt.plot(curr_df.index, curr_df['gt_corners']-curr_df['rb_corners'])
# Out:
# No handles with labels found to put in legend.

# %%
curr_df['rb_corners'][150]
# Out:
# 6

# %%
curr_df['rb_corners'][150]
# Out:
# 6

# %%
curr_df.describe()
# Out:
#         gt_corners   rb_corners         mean          max          min  \
# count  1347.000000  1347.000000  1347.000000  1347.000000  1347.000000
# mean      4.307350     4.307350    12.895320    25.448011     2.920388
# std       0.814412     0.814412    21.839948    42.758159     9.258972
# min       4.000000     4.000000     0.192973     0.323886     0.007456
# 25%       4.000000     4.000000     0.658488     1.243804     0.147432
# 50%       4.000000     4.000000     2.123456     4.703514     0.279876
# 75%       4.000000     4.000000    14.810982    28.312051     0.674444
# max      10.000000    10.000000   121.301055   179.165483    81.764483
#
#         floor_mean    floor_max    floor_min  ceiling_mean  ceiling_max  \
# count  1347.000000  1347.000000  1347.000000   1347.000000  1347.000000
# mean     11.022443    20.405499     3.146246     14.768198    24.848020
# std      19.136320    33.189081     9.559611     26.047057    42.345579
# ...

# %%
plt.hist(curr_df['gt_corners'], color='blue', edgecolor='black')
plt.semilogy()
# Out:
# []

# %%
plt.hist(curr_df['gt_corners']=4, color='blue', edgecolor='black')
# Out:
#   File "<ipython-input-6-95f4f7014c67>", line 1
#     plt.hist(curr_df['gt_corners']=4, color='blue', edgecolor='black')
#              ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
curr_df[curr_df['gt_corners']==4]
# Out:
#                   name  gt_corners  rb_corners       mean        max  \
# 0         Schlafzimmer           4           4   3.956313   8.562939
# 1                Küche           4           4  23.019122  52.605437
# 2             Bathroom           4           4   1.013833   1.950322
# 4           Essbereich           4           4   8.017758  15.642853
# 5           Wohnzimmer           4           4  18.201964  30.170499
# ...                ...         ...         ...        ...        ...
# 1341       Master Hall           4           4   1.282978   2.609153
# 1342    Master Bedroom           4           4   1.739907   4.703960
# 1343  Master Bedroom 2           4           4   0.530908   0.786997
# 1344          Zimmer I           4           4   0.880569   1.221873
# 1346         Bedroom 4           4           4   0.387328   0.762659
#
#            min  floor_mean  floor_max  floor_min  ceiling_mean  ceiling_max  \
# ...

# %%
plt.hist(curr_df[curr_df['gt_corners']==4]['mean'], color='blue', edgecolor='black')
# Out:
# (array([855., 128.,  57.,  33.,  25.,  23.,   9.,  29.,   2.,   2.]),
#  array([  0.19297306,  12.02452211,  23.85607116,  35.6876202 ,
#          47.51916925,  59.35071829,  71.18226734,  83.01381638,
#          94.84536543, 106.67691448, 118.50846352]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(curr_df[curr_df['gt_corners']==6]['mean'], color='blue', edgecolor='black')
# Out:
# (array([98., 15., 14.,  8., 13.,  5.,  3.,  2.,  2.,  2.]),
#  array([  0.28266212,  12.38450141,  24.4863407 ,  36.58817999,
#          48.69001928,  60.79185857,  72.89369786,  84.99553715,
#          97.09737644, 109.19921573, 121.30105502]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(curr_df[curr_df['gt_corners']==8]['mean'], color='blue', edgecolor='black')
# Out:
# (array([13.,  0.,  1.,  2.,  3.,  0.,  0.,  0.,  1.,  1.]),
#  array([  0.34158148,  11.09362175,  21.84566201,  32.59770228,
#          43.34974255,  54.10178281,  64.85382308,  75.60586334,
#          86.35790361,  97.10994388, 107.86198414]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(curr_df[curr_df['gt_corners']==4]['max'], color='blue', edgecolor='black')
# Out:
# (array([824., 128.,  72.,  24.,  17.,  17.,  19.,  20.,  18.,  24.]),
#  array([  0.32388634,  18.20804601,  36.09220569,  53.97636536,
#          71.86052504,  89.74468471, 107.62884439, 125.51300406,
#         143.39716374, 161.28132341, 179.16548309]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(curr_df[curr_df['gt_corners']==6]['max'], color='blue', edgecolor='black')
# Out:
# (array([83., 22.,  7., 11.,  2.,  6.,  5.,  9.,  7., 10.]),
#  array([  0.5725291 ,  18.31531146,  36.05809383,  53.8008762 ,
#          71.54365856,  89.28644093, 107.0292233 , 124.77200566,
#         142.51478803, 160.2575704 , 178.00035276]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(curr_df[curr_df['gt_corners']==8]['max'], color='blue', edgecolor='black')
# Out:
# (array([9., 4., 0., 1., 0., 1., 1., 3., 1., 1.]),
#  array([  0.82595012,  17.35588398,  33.88581784,  50.41575169,
#          66.94568555,  83.47561941, 100.00555327, 116.53548713,
#         133.06542098, 149.59535484, 166.1252887 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(curr_df[curr_df['gt_corners']==4]['floor_max'], color='blue', edgecolor='black')
# Out:
# (array([816., 136.,  79.,  29.,  30.,  21.,  24.,  13.,  11.,   4.]),
#  array([  0.17805866,  15.92278794,  31.66751722,  47.4122465 ,
#          63.15697578,  78.90170506,  94.64643435, 110.39116363,
#         126.13589291, 141.88062219, 157.62535147]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(curr_df['max'], color='blue', edgecolor='black')
# Out:
# (array([916., 154.,  80.,  36.,  19.,  24.,  25.,  33.,  26.,  34.]),
#  array([  0.32388634,  18.20804601,  36.09220569,  53.97636536,
#          71.86052504,  89.74468471, 107.62884439, 125.51300406,
#         143.39716374, 161.28132341, 179.16548309]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(curr_df['gt_corners'], curr_df['floor_max'])

# %%
# first data point

# depict first scatted plot
plt.scatter(curr_df['gt_corners'], curr_df['floor_max'], c='green')

curr_df[curr_df['gt_corners']==10]
# depict second scatted plot
#plt.scatter(x, y, c='red')
 
# depict illustration
plt.show()

# %%
curr_df['gt_corners'].unique()
# Out:
# array([ 4,  8,  6, 10], dtype=int64)

# %%
curr_df[curr_df['gt_corners']==10]
# Out:
#                 name  gt_corners  rb_corners       mean        max       min  \
# 739  Master Bathroom          10          10  13.202775  53.145464  0.195567
#
#      floor_mean  floor_max  floor_min  ceiling_mean  ceiling_max  ceiling_min
# 739    13.67592  53.145464   0.262791      12.72963      49.7854     0.195567

# %%
# first data point

# depict first scatted plot
plt.scatter(curr_df[curr_df['gt_corners']==4]['ceiling_min'], curr_df[curr_df['gt_corners']==4]['floor_min'], c='green')

plt.scatter(curr_df[curr_df['gt_corners']==6]['ceiling_min'], curr_df[curr_df['gt_corners']==6]['floor_min'], c='red')

plt.scatter(curr_df[curr_df['gt_corners']==8]['ceiling_min'], curr_df[curr_df['gt_corners']==8]['floor_min'], c='blue')

plt.scatter(curr_df[curr_df['gt_corners']==10]['ceiling_min'], curr_df[curr_df['gt_corners']==10]['floor_min'], c='black')
 
# depict illustration
plt.show()

# %%
# first data point

# depict first scatted plot
plt.scatter(curr_df[curr_df['gt_corners']==4]['ceiling_max'], curr_df[curr_df['gt_corners']==4]['floor_max'], c='green')

plt.scatter(curr_df[curr_df['gt_corners']==6]['ceiling_max'], curr_df[curr_df['gt_corners']==6]['floor_max'], c='red')

plt.scatter(curr_df[curr_df['gt_corners']==8]['ceiling_max'], curr_df[curr_df['gt_corners']==8]['floor_max'], c='blue')

plt.scatter(curr_df[curr_df['gt_corners']==10]['ceiling_max'], curr_df[curr_df['gt_corners']==10]['floor_max'], c='black')
 
# depict illustration
plt.show()

# %%
# first data point

# depict first scatted plot
plt.scatter(curr_df[curr_df['gt_corners']==4]['ceiling_mean'], curr_df[curr_df['gt_corners']==4]['floor_mean'], c='green')

plt.scatter(curr_df[curr_df['gt_corners']==6]['ceiling_mean'], curr_df[curr_df['gt_corners']==6]['floor_mean'], c='red')

plt.scatter(curr_df[curr_df['gt_corners']==8]['ceiling_mean'], curr_df[curr_df['gt_corners']==8]['floor_mean'], c='blue')

plt.scatter(curr_df[curr_df['gt_corners']==10]['ceiling_mean'], curr_df[curr_df['gt_corners']==10]['floor_mean'], c='black')

plt.legend(["4 corn" , "6 corn", "8 corn" , "10 corn"])
# depict illustration
plt.show()

# %%
plt.scatter(curr_df['floor_mean'], curr_df['ceiling_mean'], c='g')
plt.grid()
# depict illustration
plt.show()

# %%
from test_python import DrawPlots

abc = DrawPlots.draw_plots('data/deviation.json')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-5567413c523e> in <module>
#       1 from test_python import DrawPlots
#       2
# ----> 3 abc = DrawPlots.draw_plots('data/deviation.json')
#
# TypeError: draw_plots() missing 1 required positional argument: 'path_df'

# %%
from test_python import DrawPlots

all_plots = DrawPlots().draw_plots('data/deviation.json')
# Out:
# ['plots//Difference in number of corners (real and predicted).png', 'plots//Groups of rooms.png', 'plots//Deviations of max floor angles for all kind of rooms.png', 'plots//Ratio of mean deviations of floors and ceilings.png', 'plots//Ratio between mean deviations and mean floor deviations.png', 'plots//Ratio between mean deviations and mean ceiling deviations.png']

# %%
from IPython.display import Image
for plot in all_plots:
    Image(filename=plot)

# %%
import IPython.display as dp
show_plots = []
for plot in all_plots:
    show_plots.append(dp.Image(filename=plot, format='png'))

for plot in show_plots:
    dp.display_png(plot)
